# %%
from google import genai
from google.genai import types

# %%
client = genai.Client(api_key = 'AIzaSyCY_T_m5jP61pfP95POZdDHBTQTGX1lpAI')

# %%
response = client.models.generate_content(
    model = "gemini-3-flash-preview",
    contents = 'How does AI work?'
)

# %%
print(response.text)
# Out:
# At its simplest level, Artificial Intelligence (AI) works by **identifying patterns in massive amounts of data** and using those patterns to make predictions or decisions.
#
# Unlike traditional computer programs, which follow a strict list of "if-then" instructions written by a human, AI "learns" how to perform a task by looking at examples.
#
# Here is a breakdown of how the process works:
#
# ---
#
# ### 1. The Foundation: Data
# AI needs data to learn, just as a human needs experiences to learn. This data can be text, images, numbers, or recordings.
# *   **Example:** To teach an AI to recognize a cat, you feed it thousands of images labeled "cat" and thousands labeled "not a cat."
#
# ### 2. The Engine: Algorithms and Models
# An **algorithm** is a set of mathematical rules. When an algorithm is "trained" on data, it creates a **model**.
# *   **Machine Learning (ML):** This is the most common type of AI. It uses statistics to find patterns.
# *   **Neural Networks:** This is a more advanced type of ML inspired by the human brain. It consists of layers of "nodes" (artificial neurons) that pass information to one another, refining their understanding at each layer.
#
# ### 3. The Process: Training
# During training, the AI makes a guess about the data it sees.
# 1.  **Input:** The AI sees a photo.
# 2.  **Guess:** It says, "I am 60% sure this is a dog."
# 3.  **Correction:** The system is told, "No, that was a cat."
# 4.  **Adjustment:** The AI adjusts its internal mathematical connections (called **weights**) so that next time, it is more likely to get it right.
#
# This happens millions of times until the AI is highly accurate.
#
# ### 4. The Result: Inference
# Once the model is trained, it enters the "inference" phase. This is when the AI is put into the real world to handle data it has never seen before.
# *   **Example:** You upload a new photo to Google Photos, and the AI correctly labels it "Beach Trip" because it recognizes the patterns of sand and water it learned during training.
#
# ---
#
# ### How modern AI (like ChatGPT) works
# Generative AI, like the one you are talking to now, uses a specific architecture called a **Transformer**.
#
# Instead of just recognizing a cat, it predicts the **next piece of information in a sequence.**
# *   When you ask me a question, I don't "know" facts in the way humans do.
# *   Instead, I calculate the statistical probability of which word (or part of a word) should come next based on the billions of sentences I was trained on.
# *   It’s like an incredibly advanced version of "autocorrect" on your phone.
#
# ---
#
# ### Key Concepts to Remember
# *   **AI isn't "thinking":** It is performing complex math and probability. It doesn't have consciousness or feelings.
# *   **Garbage In, Garbage Out:** If you train an AI on bad, biased, or incorrect data, the AI will produce bad, biased, or incorrect results.
# *   **Narrow vs. General AI:**
#     *   **Narrow AI:** What we have today (Alexa, ChatGPT, facial recognition). It is great at specific tasks.
#     *   **General AI (AGI):** A hypothetical future AI that can do anything a human can do. This does not exist yet.
#
# ### Summary
# AI works by **taking data**, using **math to find patterns**, and then **applying those patterns** to solve problems or create new content.

# %%
chat = client.chats.create(model = 'gemini-3-flash-preview')

# %%
response = chat.send_message('I have 2 dogs in my house.')
print(response.text)
# Out:
# That sounds like a fun (and probably very busy!) household. Having two dogs can be a great experience because they often keep each other company.
#
# I'd love to hear more about them!
#
# *   **What breeds are they?** (Or are they a special mix?)
# *   **What are their names?**
# *   **Do they get along well, or are they a "chaos duo"?**
#
# If you have any questions about managing a multi-dog home, training, or nutrition, feel free to ask!

# %%
response = chat.send_message_stream('How many paws are in my house?')
for chunk in response:
  print(chunk.text, end='')
# Out:
# If it's just you and your two dogs in the house, there are **8 paws**!
#
# (Unless, of course, you're counting your own feet as paws—then there are 10!)

# %%
for message in chat.get_history():
  print(f'role - {message.role}', end=': ')
  print(message.parts[0].text)
# Out:
# role - user: I have 2 dogs in my house.
# role - model: That sounds like a fun (and probably very busy!) household. Having two dogs can be a great experience because they often keep each other company.
#
# I'd love to hear more about them!
#
# *   **What breeds are they?** (Or are they a special mix?)
# *   **What are their names?**
# *   **Do they get along well, or are they a "chaos duo"?**
#
# If you have any questions about managing a multi-dog home, training, or nutrition, feel free to ask!
# role - user: How many paws are in my house?
# role - model: If it's just you and your two dogs in the house, there are **8 paws**!
# role - model:
#
# (Unless, of course, you're counting your own feet as paws—then there are 10!)
# role - model:

# %%
from PIL import Image

# %%
image = Image.open('/content/download.jpeg')

# %%
reponse = client.models.generate_content(
    model = 'gemini-3-flash-preview',
    contents = [image, 'Tell me about this instrument']
)

# %%
print(reponse.text)
# Out:
# The instrument in the image is a **sitar**, a plucked stringed instrument that is a centerpiece of Hindustani (North Indian) classical music.
#
# Here are some key details about it:
#
# ### 1. Construction and Parts
# *   **Body (Tumba):** The large bulbous body at the bottom is usually made from a dried, hollowed-out pumpkin gourd. The top part (face) is made of wood.
# *   **Neck (Dand):** A long, hollow neck made of teak or tun wood.
# *   **Upper Resonator:** Many sitars, like the one in the photo, have a second, smaller gourd at the top of the neck to help balance the instrument and enhance its resonance.
# *   **Frets:** It features curved metal frets that are movable. Because they are raised and curved, players can pull the strings sideways to create the characteristic "gliding" notes known as *meend*.
# *   **Strings:** A sitar typically has 18 to 21 strings.
#     *   **Main strings:** 6 or 7 strings are played directly.
#     *   **Sympathetic strings (Tarab):** Located underneath the main strings, these are not plucked. Instead, they vibrate in resonance with the notes being played, giving the sitar its signature shimmering, lingering sound.
#
# ### 2. How it's Played
# *   The musician sits on the floor, holding the instrument at an angle across their lap.
# *   The strings are plucked using a wire plectrum called a **mizrab**, worn on the index finger of the right hand.
# *   The left hand is used to press the strings against the frets and pull them to change the pitch.
#
# ### 3. Its Sound
# The sitar has a very distinctive, rich, and metallic sound with complex harmonics. The combination of the hollow body and the sympathetic strings creates a "buzzing" or "twanging" quality that is instantly recognizable.
#
# ### 4. Cultural Significance
# *   **Origins:** It evolved into its current form in the 18th century in India.
# *   **Global Popularity:** While deeply rooted in ancient Indian musical traditions, the sitar became world-famous in the 1960s. This was largely due to the legendary **Ravi Shankar**, who taught **George Harrison** of The Beatles how to play, leading to its use in Western rock and pop music.
# *   **Famous Players:** Other renowned masters include Vilayat Khan, Nikhil Banerjee, and more recently, Anoushka Shankar.
